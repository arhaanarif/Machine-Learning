# %% [markdown]
# ### Logistic Regression
# #### Binary classification multiple input

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
dataset=pd.read_csv('C:\SDE\ML\LogRe_FakeData.csv')
dataset.head(3)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\S'
# <>:1: SyntaxWarning: invalid escape sequence '\S'
# C:\Users\ARHAAN ARIF\AppData\Local\Temp\ipykernel_26640\2424468457.py:1: SyntaxWarning: invalid escape sequence '\S'
#   dataset=pd.read_csv('C:\SDE\ML\LogRe_FakeData.csv')
#    cgpa  score  placed
# 0  8.07   8.76       1
# 1  7.68   6.97       1
# 2  9.49   3.18       0

# %%
sns.scatterplot(x="cgpa",y="score",data=dataset,hue="placed")
plt.show()

# %%
x=dataset.iloc[:,:-1]
y=dataset["placed"]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
lr=LogisticRegression()
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
lr.score(x_test,y_test)*100
# Out:
# 100.0

# %%
lr.predict([[8.07,8.76]])
# Out:
# c:\Users\ARHAAN ARIF\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([1])
