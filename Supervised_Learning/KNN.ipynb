# %% [markdown]
# #### KNN - K Nearest Neighbour
# #### KNN Classification

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset=pd.read_csv("C:/SDE/ML/Purchase.csv")
dataset.head(3)
# Out:
#    Age  EstimatedSalary  Purchased
# 0   58            63934          0
# 1   50           102553          1
# 2   43            87899          1

# %%
sns.scatterplot(data=dataset,x="Age",y="EstimatedSalary",hue="Purchased")
plt.show()

# %%
dataset.isnull().sum()
# Out:
# Age                0
# EstimatedSalary    0
# Purchased          0
# dtype: int64

# %%
x=dataset.iloc[:,:-1]
y=dataset["Purchased"]

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()
sc.fit(x)
# Out:
# StandardScaler()

# %%
x=pd.DataFrame(sc.transform(x),columns=x.columns)

# %%
x
# Out:
#           Age  EstimatedSalary
# 0    1.181334        -0.578459
# 1    0.589149         0.475714
# 2    0.070988         0.075707
# 3   -0.595219         0.339176
# 4   -0.151081         0.699274
# ..        ...              ...
# 995  0.070988         1.331331
# 996  1.699495        -1.148989
# 997  0.663173         1.735787
# 998 -1.187404        -1.084923
# 999 -0.965335         0.563500
#
# [1000 rows x 2 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn=KNeighborsClassifier(n_neighbors=5)
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
knn.score(x_test,y_test)*100
# Out:
# 48.0

# %%
for i in range(1,30):
    knn1=KNeighborsClassifier(n_neighbors=i)
    knn1.fit(x_train,y_train)
    print(i,knn1.score(x_train,y_train)*100,knn1.score(x_test,y_test)*100)
# Out:
# 1 100.0 47.0
# 2 74.25 46.0
# 3 75.75 51.5
# 4 68.75 49.0
# 5 70.75 48.0
# 6 66.5 46.0
# 7 66.625 45.5
# 8 63.5 46.0
# 9 64.25 43.5
# 10 62.625 45.5
# 11 59.875 42.0
# 12 60.25 44.0
# 13 61.5 46.5
# 14 58.875 43.5
# 15 58.75 45.5
# 16 59.375 45.0
# 17 60.62499999999999 47.0
# 18 60.0 46.5
# 19 60.5 46.5
# 20 59.0 44.0
# 21 59.0 44.0
# 22 60.12499999999999 43.0
# 23 58.62500000000001 42.5
# 24 59.62499999999999 43.5
# 25 57.62500000000001 41.5
# 26 58.75 42.5
# 27 58.25 42.0
# 28 59.0 43.0
# 29 59.12500000000001 43.5
